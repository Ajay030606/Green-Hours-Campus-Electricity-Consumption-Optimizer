# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("/content/green_hours_electricity_usage.csv")
df.head(10)
# Out:
#          date      time  hour day_of_week   building_name  temperature_C  \
# 0  2025-01-01  00:00:00     0   Wednesday  Sports_Complex           29.0
# 1  2025-01-01  01:00:00     1   Wednesday       Cafeteria           32.4
# 2  2025-01-01  02:00:00     2   Wednesday      Auditorium           20.3
# 3  2025-01-01  03:00:00     3   Wednesday  Sports_Complex           19.5
# 4  2025-01-01  04:00:00     4   Wednesday         Library           16.6
# 5  2025-01-01  05:00:00     5   Wednesday   Science_Block           16.9
# 6  2025-01-01  06:00:00     6   Wednesday         Library           20.6
# 7  2025-01-01  07:00:00     7   Wednesday      Auditorium           36.9
# 8  2025-01-01  08:00:00     8   Wednesday         Library           25.8
# 9  2025-01-01  09:00:00     9   Wednesday  Sports_Complex           17.6
#
#    humidity_percent  occupancy  equipment_usage  weekday  event_scheduled  \
# 0              56.6         56              5.6        1                0
# 1              41.6         42              8.8        1                0
# 2              47.0         90              2.3        1                0
# 3              45.1         41              1.8        1                1
# 4              52.1          7              9.7        1                0
# 5              52.2         77              4.5        1                0
# 6              51.4         32              6.5        1                0
# 7              43.5         68              7.6        1                0
# 8              45.1          4              5.6        1                0
# 9              39.3         26              7.0        1                1
#
#    lighting_level  AC_on  electricity_usage_kWh
# 0             5.0      0                   6.11
# 1             2.9      0                   5.36
# 2             0.6      1                   6.27
# 3             1.8      0                   5.02
# 4             3.5      0                   5.29
# 5             3.7      1                   6.39
# 6             0.7      0                   3.17
# 7             0.9      0                  11.07
# 8             4.1      1                  10.67
# 9             0.4      1                  13.22

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   2000 non-null   object
#  1   time                   2000 non-null   object
#  2   hour                   2000 non-null   int64
#  3   day_of_week            2000 non-null   object
#  4   building_name          2000 non-null   object
#  5   temperature_C          2000 non-null   float64
#  6   humidity_percent       2000 non-null   float64
#  7   occupancy              2000 non-null   int64
#  8   equipment_usage        2000 non-null   float64
#  9   weekday                2000 non-null   int64
#  10  event_scheduled        2000 non-null   int64
#  11  lighting_level         2000 non-null   float64
#  12  AC_on                  2000 non-null   int64
#  13  electricity_usage_kWh  2000 non-null   float64
# dtypes: float64(5), int64(5), object(4)
# memory usage: 218.9+ KB

# %%
df.isnull().sum()
# Out:
# date                     0
# time                     0
# hour                     0
# day_of_week              0
# building_name            0
# temperature_C            0
# humidity_percent         0
# occupancy                0
# equipment_usage          0
# weekday                  0
# event_scheduled          0
# lighting_level           0
# AC_on                    0
# electricity_usage_kWh    0
# dtype: int64

# %%
df.drop(columns=['date'],inplace=True)
df.drop(columns=['time'],inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['day_of_week']=le.fit_transform(df['day_of_week'])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['building_name']=le.fit_transform(df['building_name'])

# %%
df.head()
# Out:
#    hour  day_of_week  building_name  temperature_C  humidity_percent  \
# 0     0            6              5           29.0              56.6
# 1     1            6              2           32.4              41.6
# 2     2            6              1           20.3              47.0
# 3     3            6              5           19.5              45.1
# 4     4            6              3           16.6              52.1
#
#    occupancy  equipment_usage  weekday  event_scheduled  lighting_level  \
# 0         56              5.6        1                0             5.0
# 1         42              8.8        1                0             2.9
# 2         90              2.3        1                0             0.6
# 3         41              1.8        1                1             1.8
# 4          7              9.7        1                0             3.5
#
#    AC_on  electricity_usage_kWh
# 0      0                   6.11
# 1      0                   5.36
# 2      1                   6.27
# 3      0                   5.02
# 4      0                   5.29

# %%
x=df.drop(columns=['electricity_usage_kWh'])
x
# Out:
#       hour  day_of_week  building_name  temperature_C  humidity_percent  \
# 0        0            6              5           29.0              56.6
# 1        1            6              2           32.4              41.6
# 2        2            6              1           20.3              47.0
# 3        3            6              5           19.5              45.1
# 4        4            6              3           16.6              52.1
# ...    ...          ...            ...            ...               ...
# 1995     3            5              1           23.5              61.3
# 1996     4            5              4           25.8              79.6
# 1997     5            5              0           21.2              54.5
# 1998     6            5              1           22.6              51.3
# 1999     7            5              2           30.3              42.5
#
#       occupancy  equipment_usage  weekday  event_scheduled  lighting_level  \
# 0            56              5.6        1                0             5.0
# 1            42              8.8        1                0             2.9
# 2            90              2.3        1                0             0.6
# 3            41              1.8        1                1             1.8
# 4             7              9.7        1                0             3.5
# ...         ...              ...      ...              ...             ...
# 1995         94              8.3        1                0             1.4
# 1996         74              7.2        1                0             1.4
# 1997         85              3.1        1                0             1.0
# 1998         43              3.8        1                0             0.9
# 1999         46              2.4        1                0             2.4
#
#       AC_on
# 0         0
# 1         0
# 2         1
# 3         0
# 4         0
# ...     ...
# 1995      0
# 1996      1
# 1997      0
# 1998      0
# 1999      0
#
# [2000 rows x 11 columns]

# %%
y=df["electricity_usage_kWh"]
y
# Out:
# 0       6.11
# 1       5.36
# 2       6.27
# 3       5.02
# 4       5.29
#         ...
# 1995    6.15
# 1996    6.70
# 1997    5.83
# 1998    3.81
# 1999    8.80
# Name: electricity_usage_kWh, Length: 2000, dtype: float64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor()

# %%
ypred=model.predict(xtest)

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
mae=mean_absolute_error(ytest,ypred)
mse=mean_squared_error(ytest,ypred)
r2=r2_score(ytest,ypred)

print("mae",mae)
print("mse",mse)
print("r2",r2)
# Out:
# mae 0.6874750000000001
# mse 0.75623575
# r2 0.9237189351409033
